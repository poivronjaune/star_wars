# %%
import pandas as pd

# %%
def load_movies():
    movies = pd.read_json("raw_data/movies.json", orient="records")
    movies_df = pd.json_normalize(movies["movies"])
    return movies_df

movies = load_movies()
movies
# Out:
#                                             title episode_number  \
# 0       Star Wars: Episode I - The Phantom Menace              1
# 1    Star Wars: Episode II - Attack of the Clones              2
# 2    Star Wars: Episode III - Revenge of the Sith              3
# 3              Star Wars: Episode IV - A New Hope              4
# 4  Star Wars: Episode V - The Empire Strikes Back              5
# 5      Star Wars: Episode VI - Return of the Jedi              6
#
#                                      main_characters  \
# 0  [{'name': 'Qui-Gon Jinn'}, {'name': 'Obi-Wan K...
# 1  [{'name': 'Obi-Wan Kenobi'}, {'name': 'Anakin ...
# 2  [{'name': 'Obi-Wan Kenobi'}, {'name': 'Anakin ...
# 3  [{'name': 'Luke Skywalker'}, {'name': 'Han Sol...
# 4  [{'name': 'Luke Skywalker'}, {'name': 'Han Sol...
# 5  [{'name': 'Luke Skywalker'}, {'name': 'Han Sol...
#
#                                          description  \
# 0  The evil Trade Federation, led by Nute Gunray ...
# ...
